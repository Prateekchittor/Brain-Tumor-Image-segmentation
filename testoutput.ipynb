# %%
pip install SimpleITK
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.4/52.4 MB 13.1 MB/s eta 0:00:00
# ...

# %%
from tensorflow.keras.models import load_model

# Load the model
model = load_model('/content/drive/MyDrive/aiml/brats_3d_with_regularization_and_dropout2.hdf5')

# Print the model summary
model.summary()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 128, 128, 128,  │              0 │ -                      │
# │                           │ 3)                     │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d (Conv3D)           │ (None, 128, 128, 128,  │          1,312 │ input_layer[0][0]      │
# │                           │ 16)                    │                │                        │
# ...

# %%
from tensorflow.keras.models import load_model

# Load the model
model = load_model('/content/drive/MyDrive/aiml/brats_3d_with_regularization_and_dropout2.hdf5')

# Check the final layer
final_layer = model.layers[-1]  # Get the last layer
print("Final layer type:", type(final_layer))
print("Final layer name:", final_layer.name)
print("Final layer activation:", final_layer.activation.__name__)  # Shows the activation function
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Final layer type: <class 'keras.src.layers.convolutional.conv3d.Conv3D'>
# Final layer name: conv3d_27
# Final layer activation: softmax

# %%
import numpy as np
import matplotlib.pyplot as plt  # Ensure this is included
import tensorflow as tf
from tensorflow.keras.models import load_model
import nibabel as nib
from skimage.transform import resize

# Load the model
model = load_model('/content/drive/MyDrive/aiml/brats_3d_with_regularization_and_dropout2.hdf5')

# Load and preprocess the image (assuming the T1, T2, FLAIR images are stored as separate channels)
def load_and_preprocess_image(t1_path, t2_path, flair_path, target_size=(128, 128, 128)):
    t1 = nib.load(t1_path).get_fdata()  # Load T1 image using nibabel
    t2 = nib.load(t2_path).get_fdata()  # Load T2 image using nibabel
    flair = nib.load(flair_path).get_fdata()  # Load FLAIR image using nibabel

    # Resize to match input size expected by the model (128, 128, 128 volume)
    t1_resized = resize(t1, target_size, mode='constant', preserve_range=True)
    t2_resized = resize(t2, target_size, mode='constant', preserve_range=True)
    flair_resized = resize(flair, target_size, mode='constant', preserve_range=True)

    # Stack the sequences along the channel dimension
    input_image = np.stack([t1_resized, t2_resized, flair_resized], axis=-1)

    # Normalize if necessary (adjust depending on how the model was trained)
    input_image = input_image / np.max(input_image)

    return np.expand_dims(input_image, axis=0)  # Add batch dimension

# Define paths to the T1, T2, FLAIR images
t1_path = '/content/drive/MyDrive/aiml/patients/images/BraTS20_Training_333_t1.nii'
t2_path = '/content/drive/MyDrive/aiml/patients/images/BraTS20_Training_333_t2.nii'
flair_path = '/content/drive/MyDrive/aiml/patients/images/BraTS20_Training_333_flair.nii'

# Preprocess the input image
input_image = load_and_preprocess_image(t1_path, t2_path, flair_path)

# Make a prediction using the model
segmentation_output = model.predict(input_image)

# Post-process the output (if necessary, e.g., thresholding)
segmentation_output = (segmentation_output > 0.5).astype(np.uint8)  # Example threshold

# Select slice 65 for display (0-based index, so slice 65 is index 64)
slice_index = 68  # Index for slice 65 (0-based)

###################################################################################

print(f"Image shape: {test_img.shape}")
print(f"Output shape: {test_mask.shape}")

n_slice = 68 # You can change this to display a different slice


# Plot the images and mask
plt.figure(figsize=(18, 6))  # Wider figure to accommodate side-by-side display

# Image slices for FLAIR, T1ce, T2
if test_img.ndim == 4:  # If the image has 4 dimensions (multi-channel)
    # FLAIR
    plt.subplot(131)
    plt.imshow(test_img[:, :, n_slice, 0], cmap='gray')
    plt.title('Image FLAIR')

    # T1ce
    plt.subplot(132)
    plt.imshow(test_img[:, :, n_slice, 1], cmap='gray')
    plt.title('Image T1ce')

    # T2
    plt.subplot(133)
    plt.imshow(test_img[:, :, n_slice, 2], cmap='gray')
    plt.title('Image T2')
else:  # If the image has 3 dimensions (single channel)
    plt.subplot(131)
    plt.imshow(test_img[:, :, n_slice], cmap='gray')  # Single-channel image (grayscale)
    plt.title('Image')

    # Add the mask in the second plot
    plt.subplot(132)
    plt.imshow(test_mask[:, :, n_slice])  # Original mask color
    plt.title('Predicted Tumor Region')

# Show the plot
plt.tight_layout()  # Adjust layout for proper spacing
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step
# Image shape: (240, 240, 155)
# Output shape: (128, 128, 128)

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt  # Ensure this is included
import tensorflow as tf
from tensorflow.keras.models import load_model
import nibabel as nib
from skimage.transform import resize

# Load the model
model = load_model('/content/drive/MyDrive/aiml/brats_3d_with_regularization_and_dropout2.hdf5')

# Load and preprocess the image (assuming the T1, T2, FLAIR images are stored as separate channels)
def load_and_preprocess_image(t1_path, t2_path, flair_path, target_size=(128, 128, 128)):
    t1 = nib.load(t1_path).get_fdata()  # Load T1 image using nibabel
    t2 = nib.load(t2_path).get_fdata()  # Load T2 image using nibabel
    flair = nib.load(flair_path).get_fdata()  # Load FLAIR image using nibabel

    # Resize to match input size expected by the model (128, 128, 128 volume)
    t1_resized = resize(t1, target_size, mode='constant', preserve_range=True)
    t2_resized = resize(t2, target_size, mode='constant', preserve_range=True)
    flair_resized = resize(flair, target_size, mode='constant', preserve_range=True)

    # Stack the sequences along the channel dimension
    input_image = np.stack([t1_resized, t2_resized, flair_resized], axis=-1)

    # Normalize if necessary (adjust depending on how the model was trained)
    input_image = input_image / np.max(input_image)

    return np.expand_dims(input_image, axis=0)  # Add batch dimension

# Load the image and mask (3D arrays)
image = np.load('/content/drive/MyDrive/aiml/pp/image_99.npy')  # Replace with your image file path
mask = np.load('/content/drive/MyDrive/aiml/pp/mask_99.npy')    # Replace with your mask file path

# Choose slice 60
slice_index = 30

# Create a figure and axis to display both
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Display the image slice
ax[0].imshow(image[slice_index], cmap='gray')
ax[0].set_title(f'Image Slice {slice_index}')
ax[0].axis('off')

# Display the mask slice
ax[1].imshow(mask[slice_index], cmap='gray')
ax[1].set_title(f'Mask Slice {slice_index}')
ax[1].axis('off')

# Show the plots
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
